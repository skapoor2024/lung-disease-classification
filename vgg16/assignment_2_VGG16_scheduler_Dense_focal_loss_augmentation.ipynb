# %% [markdown]
# #### since VGG16 with focal loss was the best model, we will apply data augmentation to check if it further improves the performance of the model

# %%
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import PIL.Image as Image
import os
import math

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import EarlyStopping

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
def lr_schedule(epoch):
    initial_lr = 0.001 
    drop = 0.5  
    epochs_drop = 10 
    lr = initial_lr * math.pow(drop, math.floor((1 + epoch) / epochs_drop))
    return max(lr,0.0001)

# %%
def constant_to_tensor(x, dtype):
    
    return tf.constant(x, dtype=dtype)

# %%
def focal_categorical_crossentropy(target,output,alpha = 1.0,gamma = 2.0,axis = -1):
    
    target = tf.convert_to_tensor(target)
    output = tf.convert_to_tensor(output)
    target.shape.assert_is_compatible_with(output.shape)
    output = output / tf.reduce_sum(output, axis=axis, keepdims=True)

    epsilon_ = constant_to_tensor(1e-7, output.dtype.base_dtype)
    output = tf.clip_by_value(output, epsilon_, 1.0 - epsilon_)

    # Calculate cross entropy
    cce = -target * tf.math.log(output)

    # Calculate factors
    modulating_factor = tf.pow(1.0 - output, gamma)
    weighting_factor = tf.multiply(modulating_factor, alpha)

    # Apply weighting factor
    focal_cce = tf.multiply(weighting_factor, cce)
    focal_cce = tf.reduce_sum(focal_cce, axis=axis)
    return focal_cce

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#     for gpu in gpus:
#         tf.config.experimental.set_memory_growth(gpu, True)

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
#     horizontal_flip=True,
#     vertical_flip=True,
#     rotation_range = 20,
#     width_shift_range = 0.1,
#     height_shift_range = 0.1,
#     shear_range = 0.2,
#     zoom_range = 0.2,
#     fill_mode = 'nearest',
    rescale=1./255.0)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
main_path = os.getcwd() + '/covid_data'
aug_path = os.getcwd() + '/aug_2_covid_data'
train_dataset = train_datagen.flow_from_directory(
    directory= aug_path + '/train',
    target_size=(224, 224),
    color_mode="rgb",
    batch_size= 64,
    class_mode="categorical",
    shuffle=True,
    seed=None)

val_dataset = val_datagen.flow_from_directory(
    directory = main_path + '/validation',
    target_size=(224, 224),
    color_mode="rgb",
    batch_size= 64,
    class_mode="categorical",
    shuffle=False,
    seed=None)

test_dataset = test_datagen.flow_from_directory(
    directory = main_path + '/test',
    target_size=(224, 224),
    color_mode="rgb",
    batch_size= 64,
    class_mode="categorical",
    shuffle=False,
    seed=None)
# Out:
# Found 59234 images belonging to 4 classes.
# Found 2119 images belonging to 4 classes.
# Found 4235 images belonging to 4 classes.

# %%
for image_batch, labels_batch in train_dataset:
  print('Image Shape: {}'.format(image_batch.shape))
  print('Label Shape: {}'.format(labels_batch.shape))
  break
# Out:
# Image Shape: (64, 224, 224, 3)
# Label Shape: (64, 4)

# %%
class_weights = np.round(compute_class_weight('balanced',classes = np.arange(train_dataset.num_classes),y = train_dataset.labels),2)
class_weights_dict = dict(zip(np.arange(train_dataset.num_classes), class_weights))

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    base_model = VGG16(weights='imagenet', include_top=False)


    for layer in base_model.layers:
        layer.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024,activation = 'relu')(x)
    x= Dense(1024,activation = 'relu')(x)
    predictions = Dense(4, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss=focal_categorical_crossentropy, metrics=['categorical_accuracy'])
    history = model.fit(train_dataset, validation_data=val_dataset,  epochs=30,callbacks = [LearningRateScheduler(lr_schedule),early_stopping])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/30
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 6 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 926/926 [==============================] - 251s 259ms/step - loss: 0.2653 - categorical_accuracy: 0.7586 - val_loss: 0.1642 - val_categorical_accuracy: 0.8410
# Epoch 2/30
# 926/926 [==============================] - 238s 257ms/step - loss: 0.1806 - categorical_accuracy: 0.8193 - val_loss: 0.1600 - val_categorical_accuracy: 0.8311
# Epoch 3/30
# 926/926 [==============================] - 237s 256ms/step - loss: 0.1593 - categorical_accuracy: 0.8355 - val_loss: 0.1754 - val_categorical_accuracy: 0.8183
# Epoch 4/30
# 926/926 [==============================] - 230s 248ms/step - loss: 0.1508 - categorical_accuracy: 0.8390 - val_loss: 0.2101 - val_categorical_accuracy: 0.7919
# Epoch 5/30
# 926/926 [==============================] - 227s 245ms/step - loss: 0.1411 - categorical_accuracy: 0.8491 - val_loss: 0.1702 - val_categorical_accuracy: 0.8334
# Epoch 6/30
# 926/926 [==============================] - 227s 245ms/step - loss: 0.1355 - categorical_accuracy: 0.8534 - val_loss: 0.1798 - val_categorical_accuracy: 0.8013
# Epoch 7/30
# 926/926 [==============================] - 228s 246ms/step - loss: 0.1312 - categorical_accuracy: 0.8548 - val_loss: 0.1293 - val_categorical_accuracy: 0.8513
# Epoch 8/30
# 926/926 [==============================] - 226s 244ms/step - loss: 0.1276 - categorical_accuracy: 0.8586 - val_loss: 0.1694 - val_categorical_accuracy: 0.8457
# Epoch 9/30
# 926/926 [==============================] - 229s 247ms/step - loss: 0.1232 - categorical_accuracy: 0.8611 - val_loss: 0.1899 - val_categorical_accuracy: 0.8226
# Epoch 10/30
# 926/926 [==============================] - 231s 249ms/step - loss: 0.1077 - categorical_accuracy: 0.8767 - val_loss: 0.1401 - val_categorical_accuracy: 0.8556
# Epoch 11/30
# 926/926 [==============================] - 228s 246ms/step - loss: 0.1058 - categorical_accuracy: 0.8776 - val_loss: 0.1338 - val_categorical_accuracy: 0.8617
# Epoch 12/30
# 926/926 [==============================] - 235s 254ms/step - loss: 0.1025 - categorical_accuracy: 0.8804 - val_loss: 0.1373 - val_categorical_accuracy: 0.8627
# Epoch 13/30
# 926/926 [==============================] - 235s 254ms/step - loss: 0.0999 - categorical_accuracy: 0.8801 - val_loss: 0.1430 - val_categorical_accuracy: 0.8598
# Epoch 14/30
# 926/926 [==============================] - 230s 248ms/step - loss: 0.0986 - categorical_accuracy: 0.8843 - val_loss: 0.1325 - val_categorical_accuracy: 0.8598
# Epoch 15/30
# 926/926 [==============================] - 231s 250ms/step - loss: 0.0955 - categorical_accuracy: 0.8864 - val_loss: 0.1283 - val_categorical_accuracy: 0.8683
# Epoch 16/30
# 926/926 [==============================] - 234s 253ms/step - loss: 0.0924 - categorical_accuracy: 0.8887 - val_loss: 0.1693 - val_categorical_accuracy: 0.8424
# Epoch 17/30
# 926/926 [==============================] - 233s 251ms/step - loss: 0.0915 - categorical_accuracy: 0.8887 - val_loss: 0.1291 - val_categorical_accuracy: 0.8655
# Epoch 18/30
# 926/926 [==============================] - 233s 252ms/step - loss: 0.0901 - categorical_accuracy: 0.8892 - val_loss: 0.1392 - val_categorical_accuracy: 0.8594
# Epoch 19/30
# 926/926 [==============================] - 229s 248ms/step - loss: 0.0876 - categorical_accuracy: 0.8928 - val_loss: 0.1557 - val_categorical_accuracy: 0.8377
# Epoch 20/30
# 926/926 [==============================] - 235s 254ms/step - loss: 0.0771 - categorical_accuracy: 0.9025 - val_loss: 0.1387 - val_categorical_accuracy: 0.8655
# Epoch 21/30
# 926/926 [==============================] - 241s 261ms/step - loss: 0.0752 - categorical_accuracy: 0.9032 - val_loss: 0.1558 - val_categorical_accuracy: 0.8664
# Epoch 22/30
# 926/926 [==============================] - 248s 268ms/step - loss: 0.0737 - categorical_accuracy: 0.9054 - val_loss: 0.1440 - val_categorical_accuracy: 0.8731
# Epoch 23/30
# 926/926 [==============================] - 245s 264ms/step - loss: 0.0727 - categorical_accuracy: 0.9051 - val_loss: 0.1318 - val_categorical_accuracy: 0.8754
# Epoch 24/30
# 926/926 [==============================] - 245s 264ms/step - loss: 0.0710 - categorical_accuracy: 0.9074 - val_loss: 0.1760 - val_categorical_accuracy: 0.8537
# Epoch 25/30
# 926/926 [==============================] - 244s 263ms/step - loss: 0.0701 - categorical_accuracy: 0.9096 - val_loss: 0.1463 - val_categorical_accuracy: 0.8646

# %%
plt.figure(figsize = (20, 20))
plt.subplot(341)
plt.plot(history.history['loss'], color='blue', linestyle = 'dashdot', label='Train')
plt.plot(history.history['val_loss'], color='red', linestyle="solid", label='Val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.grid(visible = True, which = 'both', color= 'r', linestyle = 'dotted')
plt.legend()

plt.subplot(343)
plt.plot(history.history['categorical_accuracy'], color='blue', linestyle = 'dashdot', label='Train')
plt.plot(history.history['val_categorical_accuracy'], color='red', linestyle="solid", label='Val')
# plt.xticks(np.arange(0, 31, step=2))  # Set label locations.
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.grid(visible = True, which = 'both', color= 'r', linestyle = 'dotted')
plt.legend()

# %%
test_result = model.evaluate(test_dataset, batch_size = 128)
# Out:
# 67/67 [==============================] - 21s 305ms/step - loss: 0.1452 - categorical_accuracy: 0.8555

# %%
print('Test Loss: {}'.format(test_result[0]))
print('Test Accuracy: {}'.format(test_result[1]))
# Out:
# Test Loss: 0.14516009390354156
# Test Accuracy: 0.85548996925354

# %%
class_names = list(train_dataset.class_indices)

# %%
label_names = class_names
y_pred = model.predict(test_dataset, batch_size=128)
y_test = test_dataset.labels
cm = tf.math.confusion_matrix(y_test, 
                              y_pred.argmax(axis=1),
                              num_classes = 4)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, xticklabels=class_names, yticklabels=class_names, 
              annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.savefig('CM.png', dpi = 300)
plt.show()
